# %%
# CLI interface for a contact book:
"""
Approach/ Work Flow:
    we need a loop for user for their choices.
    each choice is given a seperate function to handle the case.
    to exit the loop, we need a flag until the choice of exit is made it stays True else False.
"""

def add_Contact(contact, value):
    if (contact in contacts) and contacts[contact] == value:
        return "Contact already exists"
    elif (contact in contacts) and contacts[contact] != value:
        contacts[contact] += " , " + value
    else:
        contacts[contact] = value

def search_Contact(key):
    if key in contacts:
        return key, contacts[key]
    else:
        return "Contact doesn't exist"

def display_Contact():
    if contacts == {}:
        return "Contact list is empty"
    return contacts

def delete_contact(contact) :
    if contact in contacts:
        del contacts[contact]
        print("Contact has been deleted")
    else:
        print( "Contact is not in Contact list")

contacts = {}
flag = True
while flag:
    print("\n**What do you want to do now?\n 1) Add a contact\n 2) Search for a contact\n 3) Display all Contacts\n 4) Delete Contact\n 5)Exit")
    choice = int(input("Your choice? -> "))
    match choice:
        case 1:
            contact = input("Name of person: ")
            value = input("Contact:")
            add_Contact(contact, value)
        case 2:
             key = input("Which Contact to Search? ")
             print(search_Contact(key))
        case 3:
            print(display_Contact())
        case 4:
            contact = input("Which contact do you want to Delete: ")
            delete_contact(contact)
        case 5:
            print("Thanks for using Me")
            flag = False
        case _:
            print("There is no such Operation to perform. Please select again")
# Out:
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 3
# Contact list is empty
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 1
# Name of person: Aditya
# Contact:8767346448
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 1
# Name of person: Mummi
# Contact:9270150147
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 1
# Name of person: Papa
# Contact:8888819239
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 3
# {'Aditya': '8767346448', 'Mummi': '9270150147', 'Papa': '8888819239'}
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 2
# Which Contact to Search? Madhuri
# Contact doesn't exist
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 2
# Which Contact to Search? Mummi
# ('Mummi', '9270150147')
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 2
# Which Contact to Search? Papa
# ('Papa', '8888819239')
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 4
# Which contact do you want to Delete: Aditya
# Contact has been deleted
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 3
# {'Mummi': '9270150147', 'Papa': '8888819239'}
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 4
# Which contact do you want to Delete: Adityaa
#
# **What do you want to do now?
#  1) Add a contact
#  2) Search for a contact
#  3) Display all Contacts
#  4) Delete Contact
#  5)Exit
# Your choice? -> 5
# Thanks for using Me
